# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%writefile app.py
import streamlit as st
from ultralytics import YOLO
from PIL import Image
import numpy as np

# Load YOLO model (adjust model path as needed)
model = YOLO("/content/drive/MyDrive/yolo_runs/flood_detection2/weights/best.pt")

st.title("Flood Detection Demo")

uploaded_file = st.file_uploader("Upload an image", type=["jpg", "jpeg", "png"])
if uploaded_file is not None:
    image = Image.open(uploaded_file).convert("RGB")
    st.image(image, caption="Uploaded Image", use_column_width=True)

    img_array = np.array(image)
    results = model.predict(source=img_array, imgsz=640, conf=0.25)

    st.image(results[0].plot(), caption="Prediction Result", use_column_width=True)
# Out:
# Writing app.py

# %%
# !npm install -g localtunnel
# !lt --port 8501
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸
# added 22 packages in 3s
# ⠸
# ⠸3 packages are looking for funding
# ⠸  run `npm fund` for details
# ⠸your url is: https://nasty-loops-float.loca.lt

# %%
# !curl https://loca.lt/mytunnelpassword
# Out:
# 34.106.123.155

# %%
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dataset downloaded to: <roboflow.core.dataset.Dataset object at 0x78edb7ec4950>

# %%
# Out:
# Dataset downloaded to folder: /content/Houses_in_Flood-6
# ['test', 'valid', 'README.roboflow.txt', 'README.dataset.txt', 'data.yaml', 'train']
# ...

# %%
model = YOLO("/content/drive/MyDrive/yolo_runs/flood_detection2/weights/best.pt")

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/yolo_runs/flood_detection2/weights/best.pt")

# %%
import os
print(os.path.exists("/content/drive/MyDrive/yolo_runs/flood_detection2/weights/best.pt"))
# Out:
# True

# %%
# Example: Predict on one test image and save results
test_img_path = "/content/Houses_in_Flood-6/test/images/flood_image0505_jpg.rf.7a6f8e9ee1b7f534fc140a53f637bada.jpg"
results = model.predict(source=test_img_path, save=True, imgsz=640, conf=0.3)
print("Prediction completed. Check saved images in runs/detect/predict or your specified folder.")
# Out:
# image 1/1 /content/Houses_in_Flood-6/test/images/flood_image0505_jpg.rf.7a6f8e9ee1b7f534fc140a53f637bada.jpg: 640x640 1 Partially-Flooded, 899.2ms
# Speed: 15.2ms preprocess, 899.2ms inference, 54.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict
# Prediction completed. Check saved images in runs/detect/predict or your specified folder.

# %%
from IPython.display import Image, display

# Path to the saved prediction image (it usually has same filename as input image)
save_dir = "/content/runs/detect/predict"
predicted_img_path = save_dir + "/flood_image0505_jpg.rf.7a6f8e9ee1b7f534fc140a53f637bada.jpg"

display(Image(filename=predicted_img_path))

# %%
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# INFO:werkzeug:Press CTRL+C to quit
